# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %run Classes.py

# %%
agent = gridAgent(5, random_state=2)
agent.play(20_000)

# %%
# TODO: Add draw_heatmap as method for agent class
plt.figure(figsize=(12,7))
sns.heatmap(agent.exp_grid, cmap='magma', annot=True)
plt.text(agent.path[0][1]+0.5,agent.path[0][0]+0.8,'START',verticalalignment='center',horizontalalignment='center')
plt.text(agent.reward_pos[1]+0.5,agent.reward_pos[0]+0.8,'END',verticalalignment='center',horizontalalignment='center')
plt.show()

# %%
agent.reset()

# %%
policy = agent.policy()
print(policy)
agent.action(policy)
agent.draw_grid()
# Out:
# down
